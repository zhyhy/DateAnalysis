# %%
# 第十三章 python 建模库介绍

# %%
# 开发模型的重要环节是特征工程。
# 本书中俄数据聚合和 Groupby 工具常常用于特征工程之中

# %%
import pandas as pd

# %%
import numpy as np

# %%
data = pd.DataFrame({
                    'x0':[1,2,3,4,5],
                    'x1':[0.01,-0.01,0.25,-4.1,0],
                    'y':[-1.5,0,3.6,1.3,-2]
})

# %%
data
# Out:
#    x0    x1    y
# 0   1  0.01 -1.5
# 1   2 -0.01  0.0
# 2   3  0.25  3.6
# 3   4 -4.10  1.3
# 4   5  0.00 -2.0

# %%
data.columns
# Out:
# Index(['x0', 'x1', 'y'], dtype='object')

# %%
data.values
# Out:
# array([[ 1.  ,  0.01, -1.5 ],
#        [ 2.  , -0.01,  0.  ],
#        [ 3.  ,  0.25,  3.6 ],
#        [ 4.  , -4.1 ,  1.3 ],
#        [ 5.  ,  0.  , -2.  ]])

# %%
# 使用 .values 属性，可以将 DF 转换为 NP数组

# %%
df2 = pd.DataFrame(data.values,columns=['one','two','three'])

# %%
df2
# Out:
#    one   two  three
# 0  1.0  0.01   -1.5
# 1  2.0 -0.01    0.0
# 2  3.0  0.25    3.6
# 3  4.0 -4.10    1.3
# 4  5.0  0.00   -2.0

# %%
# 可以重新分配列名

# %%
df3 = data.copy()

# %%
df3
# Out:
#    x0    x1    y
# 0   1  0.01 -1.5
# 1   2 -0.01  0.0
# 2   3  0.25  3.6
# 3   4 -4.10  1.3
# 4   5  0.00 -2.0

# %%
data
# Out:
#    x0    x1    y
# 0   1  0.01 -1.5
# 1   2 -0.01  0.0
# 2   3  0.25  3.6
# 3   4 -4.10  1.3
# 4   5  0.00 -2.0

# %%
df3['strings'] = ['a','b','c','d','e']

# %%
df3
# Out:
#    x0    x1    y strings
# 0   1  0.01 -1.5       a
# 1   2 -0.01  0.0       b
# 2   3  0.25  3.6       c
# 3   4 -4.10  1.3       d
# 4   5  0.00 -2.0       e

# %%
# 对于一些模型，可能只想使用列的子集，可以使用loc，用values做索引

# %%
model_cols = ['x0','x1']

# %%
data.loc[;,model_cols.values]
# Out:
#   File "<ipython-input-25-1e74397e2b4e>", line 1
#     data.loc[;,model_cols.values]
#              ^
# SyntaxError: invalid syntax

# %%
data.loc[:,model_cols].values
# Out:
# array([[ 1.  ,  0.01],
#        [ 2.  , -0.01],
#        [ 3.  ,  0.25],
#        [ 4.  , -4.1 ],
#        [ 5.  ,  0.  ]])

# %%
# scikit-learn介绍

# %%
# sklearn 通常不能接收缺失数据

# %%
train = pd.read_csv('datasets/titanic/train.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-94679651f034> in <module>()
# ----> 1 train = pd.read_csv('datasets/titanic/train.csv')
#
# F:\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
# ...

# %%
# 第十四章

# %%
#Python有内置或第三方模块可以将JSON字符串转换成Python字典对象。这里， 我将使用json模块及其loads函数逐行加载已经下载好的数据文件：

# %%
import json

# %%
path = 'datasets/bitly_usagov/example.txt'

# %%
records = [json.loads(line) for line in open(path)]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-b1e0b494454a> in <module>()
# ----> 1 records = [json.loads(line) for line in open(path)]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datasets/bitly_usagov/example.txt'

# %%
# 想要知道数据集中最常出现的是哪个字段，tz字段

# %%
# 然后我通过take按照这个顺序截取了后10行大值：

# %%
#按"diff"排序即可得到分歧大且女性观众更喜欢的电影：

# %%
# 最受欢迎的名字

# %%
 import pandas as pd

# %%
 names1880 = pd.read_csv('names/yob1880.txt',                names=['name', 'sex', 'births'])

# %%
names1880
# Out:
#            name sex  births
# 0          Mary   F    7065
# 1          Anna   F    2604
# 2          Emma   F    2003
# 3     Elizabeth   F    1939
# 4        Minnie   F    1746
# 5      Margaret   F    1578
# 6           Ida   F    1472
# 7         Alice   F    1414
# 8        Bertha   F    1320
# 9         Sarah   F    1288
# 10        Annie   F    1258
# 11        Clara   F    1226
# 12         Ella   F    1156
# 13     Florence   F    1063
# 14         Cora   F    1045
# 15       Martha   F    1040
# 16        Laura   F    1012
# 17       Nellie   F     995
# 18        Grace   F     982
# 19       Carrie   F     949
# 20        Maude   F     858
# 21        Mabel   F     808
# 22       Bessie   F     796
# 23       Jennie   F     793
# 24     Gertrude   F     787
# 25        Julia   F     783
# 26       Hattie   F     769
# 27        Edith   F     768
# 28       Mattie   F     704
# 29         Rose   F     700
# ...         ...  ..     ...
# 1970      Philo   M       5
# ...

# %%
names1880.head()
# Out:
#         name sex  births
# 0       Mary   F    7065
# 1       Anna   F    2604
# 2       Emma   F    2003
# 3  Elizabeth   F    1939
# 4     Minnie   F    1746

# %%
# 先按男女分开

# %%
names1880.groupby('sex').births.sum()
# Out:
# sex
# F     90993
# M    110491
# Name: births, dtype: int64

# %%
years = range(1880, 2011)

# %%
pieces = [] 
columns = ['name', 'sex', 'births']

# %%
for year in years:   
    path = 'names/yob%d.txt' % year     
    frame = pd.read_csv(path, names=columns) 
    frame['year'] = year    
    pieces.append(frame) 
names = pd.concat(pieces, ignore_index=True)
# 这个数据集被分割成了多个文件，将所有数据都组装到一个DF里面，加上一个year字段，使用pd.concat

# %%
names
# Out:
#               name sex  births  year
# 0             Mary   F    7065  1880
# 1             Anna   F    2604  1880
# 2             Emma   F    2003  1880
# 3        Elizabeth   F    1939  1880
# 4           Minnie   F    1746  1880
# 5         Margaret   F    1578  1880
# 6              Ida   F    1472  1880
# 7            Alice   F    1414  1880
# 8           Bertha   F    1320  1880
# 9            Sarah   F    1288  1880
# 10           Annie   F    1258  1880
# 11           Clara   F    1226  1880
# 12            Ella   F    1156  1880
# 13        Florence   F    1063  1880
# 14            Cora   F    1045  1880
# 15          Martha   F    1040  1880
# 16           Laura   F    1012  1880
# 17          Nellie   F     995  1880
# 18           Grace   F     982  1880
# 19          Carrie   F     949  1880
# 20           Maude   F     858  1880
# 21           Mabel   F     808  1880
# 22          Bessie   F     796  1880
# 23          Jennie   F     793  1880
# ...

# %%
# 得到了全部数据之后，就可以利用groupby或pivot_table在year和sex级别上对其进行聚合

# %%
total_births = names.pivot_table('births', index='year',columns='sex', aggfunc=sum)

# %%
total_births
# Out:
# sex         F        M
# year
# 1880    90993   110491
# 1881    91953   100743
# 1882   107847   113686
# 1883   112319   104627
# 1884   129020   114442
# 1885   133055   107799
# 1886   144533   110784
# 1887   145981   101413
# 1888   178622   120851
# 1889   178366   110580
# 1890   190376   111025
# 1891   185481   101191
# 1892   212339   122036
# 1893   212905   112318
# 1894   222921   115769
# 1895   233627   117395
# 1896   237918   119567
# 1897   234200   112757
# 1898   258768   122690
# 1899   233023   106210
# 1900   299800   150483
# 1901   239345   106469
# 1902   264076   122660
# 1903   261971   119233
# 1904   275364   128125
# 1905   291619   132312
# 1906   295303   133158
# 1907   318566   146829
# 1908   334313   154339
# 1909   347230   163998
# ...       ...      ...
# 1981  1667773  1791409
# 1982  1693053  1814611
# 1983  1670371  1792455
# 1984  1683380  1804440
# 1985  1720425  1847650
# 1986  1715074  1840797
# 1987  1738220  1866183
# ...

# %%
total_births.plot(title='Total births by sex and year')

# %%
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-c4e69632d98a> in <module>()
# ----> 1 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# %%
plt.show()

# %%
# 插入一个prop列，用于存放指定名字的婴儿数相对于总出书是

# %%
def add_prop(group):
    group['prop'] = group.births / group.births.sum()
    return group

# %%
names = names.groupby(['year','sex']).apply(add_prop)

# %%
names
# Out:
#               name sex  births  year      prop
# 0             Mary   F    7065  1880  0.077643
# 1             Anna   F    2604  1880  0.028618
# 2             Emma   F    2003  1880  0.022013
# 3        Elizabeth   F    1939  1880  0.021309
# 4           Minnie   F    1746  1880  0.019188
# 5         Margaret   F    1578  1880  0.017342
# 6              Ida   F    1472  1880  0.016177
# 7            Alice   F    1414  1880  0.015540
# 8           Bertha   F    1320  1880  0.014507
# 9            Sarah   F    1288  1880  0.014155
# 10           Annie   F    1258  1880  0.013825
# 11           Clara   F    1226  1880  0.013474
# 12            Ella   F    1156  1880  0.012704
# 13        Florence   F    1063  1880  0.011682
# 14            Cora   F    1045  1880  0.011484
# 15          Martha   F    1040  1880  0.011429
# 16           Laura   F    1012  1880  0.011122
# 17          Nellie   F     995  1880  0.010935
# 18           Grace   F     982  1880  0.010792
# ...

# %%
# 验证所有分组的 prop 的总和是否为1

# %%
names.groupby(['year','sex']).prop.sum()
# Out:
# year  sex
# 1880  F      1.0
#       M      1.0
# 1881  F      1.0
#       M      1.0
# 1882  F      1.0
#       M      1.0
# 1883  F      1.0
#       M      1.0
# 1884  F      1.0
#       M      1.0
# 1885  F      1.0
#       M      1.0
# 1886  F      1.0
#       M      1.0
# 1887  F      1.0
#       M      1.0
# 1888  F      1.0
#       M      1.0
# 1889  F      1.0
#       M      1.0
# 1890  F      1.0
#       M      1.0
# 1891  F      1.0
#       M      1.0
# 1892  F      1.0
#       M      1.0
# 1893  F      1.0
#       M      1.0
# 1894  F      1.0
#       M      1.0
#             ...
# 1996  F      1.0
#       M      1.0
# 1997  F      1.0
#       M      1.0
# 1998  F      1.0
#       M      1.0
# 1999  F      1.0
#       M      1.0
# 2000  F      1.0
#       M      1.0
# 2001  F      1.0
#       M      1.0
# 2002  F      1.0
#       M      1.0
# 2003  F      1.0
#       M      1.0
# 2004  F      1.0
#       M      1.0
# 2005  F      1.0
#       M      1.0
# 2006  F      1.0
# ...

# %%
# 分析命名趋势

# %%
def get_top1000(group): 
     return group.sort_values(by='births', ascending=False)[:1000]

# %%
grouped = names.groupby(['year', 'sex'])

# %%
grouped

# %%
top1000 = grouped.apply(get_top1000)

# %%
top1000
# Out:
#                        name sex  births  year      prop
# year sex
# 1880 F   0             Mary   F    7065  1880  0.077643
#          1             Anna   F    2604  1880  0.028618
#          2             Emma   F    2003  1880  0.022013
#          3        Elizabeth   F    1939  1880  0.021309
#          4           Minnie   F    1746  1880  0.019188
#          5         Margaret   F    1578  1880  0.017342
#          6              Ida   F    1472  1880  0.016177
#          7            Alice   F    1414  1880  0.015540
#          8           Bertha   F    1320  1880  0.014507
#          9            Sarah   F    1288  1880  0.014155
#          10           Annie   F    1258  1880  0.013825
#          11           Clara   F    1226  1880  0.013474
#          12            Ella   F    1156  1880  0.012704
#          13        Florence   F    1063  1880  0.011682
#          14            Cora   F    1045  1880  0.011484
#          15          Martha   F    1040  1880  0.011429
# ...
