# %%
# 第九章

# %%
import matplotlib.pyplot as plt

# %%
import numpy as mp
import pandas as pd

# %%
import numpy as np

# %%
data = np.arrange(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-9834cee2aa38> in <module>()
# ----> 1 data = np.arrange(10)
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
data = np.arange(10)

# %%
plt.plot(data)

# %%
plt.show()

# %%
# mataplot.pyplot 是一个画图的快捷方式

# %%
#matplotlib 的图像都位于 Figure 对象中

# %%
fig = plt.figure()

# %%
ax1 = fig.add_subplot(2,2,1)

# %%
ax2 = fig.add_subplot(2,2,2)

# %%
ax3 = fig.add_subplot(2,2,3)

# %%
ax4 = fig.add_subplot(2,2,4)

# %%
plt.plot(data)

# %%
plt.show()

# %%
# 一种常用的创建figure和axs的方法

# %%
fig, axes = plt.subplot(2,3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-2da3947ea1a2> in <module>()
# ----> 1 fig, axes = plt.subplot(2,3)
#
# F:\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1042
#    1043     fig = gcf()
# -> 1044     a = fig.add_subplot(*args, **kwargs)
#    1045     bbox = a.bbox
#    1046     byebye = []
#
# F:\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1019                     self._axstack.remove(ax)
#    1020
# -> 1021             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1022
#    1023         self._axstack.add(key, a)
#
# F:\Anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      66                 # num - 1 for converting from MATLAB to python indexing
#      67         else:
# ...

# %%
fig,axes = plt.subplots(2,3)

# %%
# 注意是subplots

# %%
#sharex，sharey可以共用x轴和y轴

# %%
#调整subplot周围的间距

# %%
fig, axes = plt.subplots(2,2,sharex =True,sharey = True)

# %%
for i in range(2):
    for j in range(2):
# Out:
#   File "<ipython-input-25-098f30ad8fc6>", line 2
#     for j in range(2):
#                       ^
# SyntaxError: unexpected EOF while parsing

# %%
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(500),bins = 50,color = 'k',alpha = 0.5)
plt.subplots_adjust(wspace = 0,hspace = 0)

# %%
plt.show()

# %%
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(500),bins = 50,color = 'k',alpha = 0.5)
plt.subplots_adjust(wspace = 0.1,hspace = 0.1)

# %%
plt.show()

# %%
plt.show()

# %%
plt.show()

# %%
fig, axes = plt.subplots(2,2,sharex =True,sharey = True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(500),bins = 50,color = 'k',alpha = 0.5)
plt.subplots_adjust(wspace = 0.1,hspace = 0.1)

# %%
plt.show()

# %%
fig, axes = plt.subplots(2,2,sharex =True,sharey = True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(500),bins = 50,color = 'k',alpha = 0.5)
plt.subplots_adjust(wspace = 0.5,hspace = 0.5)
plt.show()

# %%
plot?
# Out:
# Object `plot` not found.

# %%
plt.plot(np.random.randn(300).cumsum(),'ko--')

# %%
plt.show()

# %%
plt.plot(np.random.randn(300).cumsum(),color = 'k', linestyle = 'dashed',marker = '0')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# F:\Anaconda3\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     264             try:
# --> 265                 Path(marker)
#     266                 self._marker_function = self._set_vertices
#
# F:\Anaconda3\lib\site-packages\matplotlib\path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     140             msg = "'vertices' must be a 2D list or array with shape Nx2"
# --> 141             raise ValueError(msg)
#     142
#
# ValueError: 'vertices' must be a 2D list or array with shape Nx2
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-3714d2138b53> in <module>()
# ...

# %%
plt.plot(np.random.randn(300).cumsum(),color = 'k', linestyle = 'dashed',marker = 'o')

# %%
plt.show()

# %%
plt.plot(np.random.randn(300).cumsum(),color = 'k', linestyle = 'dashed',marker = 'b')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# F:\Anaconda3\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     264             try:
# --> 265                 Path(marker)
#     266                 self._marker_function = self._set_vertices
#
# F:\Anaconda3\lib\site-packages\matplotlib\path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     136         else:
# --> 137             vertices = np.asarray(vertices, np.float_)
#     138
#
# F:\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#
# ValueError: could not convert string to float: 'b'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
# pyplot 含有诸如 xlim、xticks和xticklabels之类的方法，分别控制图表的范围，刻度位置，刻度标签等，注意是方法

# %%
# 调用不含参数，plt.xlim()返回当前x轴的范围    调用带参数，设置参数值  plt.xlim([0,10]) 将x轴的范围设置为 0 到 10

# %%
# 其实本质上 plt.xlim()对应ax.get_xlim   plt.xlim([0,10])对应 ax.set_xlim()

# %%
# 设置标签、轴标签、刻度以及刻度标签

# %%
fig = plt.figure()

# %%
ax = fig.add_subplot(1,1,1)

# %%
ax.plot(np.random.randn(1000).cumsum())

# %%
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-104bfcfa303e> in <module>()
# ----> 1 plot.show()
#
# NameError: name 'plot' is not defined

# %%
plt.show()

# %%
fig = plt.figure()

# %%
fig, axes = plt.subplots(1,1,sharex =True,sharey = True)

# %%
axes.plt(np.random.randn(1000).cumsum())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-75aa8c1b7728> in <module>()
# ----> 1 axes.plt(np.random.randn(1000).cumsum())
#
# AttributeError: 'AxesSubplot' object has no attribute 'plt'

# %%
axes.plot(np.random.randn(1000).cumsum())

# %%
plt.show()

# %%
# 接下来改变 x 轴刻度，set_xticks 和 set_xticklabels

# %%
ticks = ax.set_xticks([0,250,500,700,1000])

# %%
labels = ax.set_xticklabels(['one','two','three','four','five'],rotation = 30,fontsize = 'small')

# %%
plt.show()

# %%
fig, axes = plt.subplots(1,1,sharex =True,sharey = True)
axes.plot(np.random.randn(1000).cumsum()))
# Out:
#   File "<ipython-input-60-c4414d298fed>", line 2
#     axes.plot(np.random.randn(1000).cumsum()))
#                                              ^
# SyntaxError: invalid syntax

# %%
fig, axes = plt.subplots(1,1,sharex =True,sharey = True)
axes.plot(np.random.randn(1000).cumsum())
ticks = ax.set_xticks = ([0,250,500,700,1000])
labels = ax.set_xticklabels(['one','two','three','four','five'],rotation = 30,fontsize = 'small')
plt.show()

# %%
fig, axes = plt.subplots(1,1,sharex =True,sharey = True)
axes.plot(np.random.randn(1000).cumsum())
ax.set_xticks = ([0,250,500,700,1000])
ax.set_xticklabels(['one','two','three','four','five'],rotation = 30,fontsize = 'small')
ax.set_xlable('Stages')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-493278e630df> in <module>()
#       3 ax.set_xticks = ([0,250,500,700,1000])
#       4 ax.set_xticklabels(['one','two','three','four','five'],rotation = 30,fontsize = 'small')
# ----> 5 ax.set_xlable('Stages')
#       6 plt.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_xlable'

# %%
fig, axes = plt.subplots(1,1,sharex =True,sharey = True)
axes.plot(np.random.randn(1000).cumsum())
ax.set_xticks = ([0,250,500,700,1000])
ax.set_xticklabels(['one','two','three','four','five'],rotation = 30,fontsize = 'small')
ax.set_xlables('Stages')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-9790a42c05d3> in <module>()
#       3 ax.set_xticks = ([0,250,500,700,1000])
#       4 ax.set_xticklabels(['one','two','three','four','five'],rotation = 30,fontsize = 'small')
# ----> 5 ax.set_xlables('Stages')
#       6 plt.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_xlables'

# %%
fig, axes = plt.subplots(1,1,sharex =True,sharey = True)
axes.plot(np.random.randn(1000).cumsum())
ax.set_xticks = ([0,250,500,700,1000])
ax.set_xticklabels(['one','two','three','four','five'],rotation = 30,fontsize = 'small')
ax.set_xlabel('Stages')
plt.show()

# %%
fig, ax = plt.subplots(1,1,sharex =True,sharey = True)
axes.plot(np.random.randn(1000).cumsum())
ax.set_xticks = ([0,250,500,700,1000])
ax.set_xticklabels(['one','two','three','four','five'],rotation = 30,fontsize = 'small')
ax.set_xlabel('Stages')
plt.show()

# %%
fig, ax = plt.subplots(1,1,sharex =True,sharey = True)
ax.plot(np.random.randn(1000).cumsum())
ax.set_xticks = ([0,250,500,700,1000])
ax.set_xticklabels(['one','two','three','four','five'],rotation = 30,fontsize = 'small')
ax.set_xlabel('Stages')
plt.show()

# %%
fig, ax = plt.subplots(1,1,sharex =True,sharey = True)
ax.plot(np.random.randn(1000).cumsum())
ax.set_xticks = ([0,250,500,700,1000])
ax.set_xticklabels(['one','two','three','four','five'],rotation = 30,fontsize = 'small')
ax.set_xlabel('Stages')
ax.set_title('i LOVE LEARN')
plt.show()

# %%
# 也可以批量 set

# %%
fig, ax = plt.subplots(1,1,sharex =True,sharey = True)
ax.plot(np.random.randn(1000).cumsum())
ax.set_xticks = ([0,250,500,700,1000])
ax.set_xticklabels(['one','two','three','four','five'],rotation = 30,fontsize = 'small')
#ax.set_xlabel('Stages')
#ax.set_title('i LOVE LEARN')
plt.show()
props = {
    'titl':'Myfirst',
    'xlabel':'Stage'
}
ax.set(**props)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-762c4e660289> in <module>()
#      10     'xlabel':'Stage'
#      11 }
# ---> 12 ax.set(**props)
#
# F:\Anaconda3\lib\site-packages\matplotlib\artist.py in set(self, **kwargs)
#     981                    key=lambda x: (self._prop_order.get(x[0], 0), x[0])))
#     982
# --> 983         return self.update(props)
#     984
#     985     def findobj(self, match=None, include_self=True):
#
# F:\Anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#     883         try:
#     884             ret = [_update_property(self, k, v)
# --> 885                    for k, v in props.items()]
#     886         finally:
#     887             self.eventson = store
#
# F:\Anaconda3\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#     883         try:
# ...

# %%
fig, ax = plt.subplots(1,1,sharex =True,sharey = True)
ax.plot(np.random.randn(1000).cumsum())
ax.set_xticks = ([0,250,500,700,1000])
ax.set_xticklabels(['one','two','three','four','five'],rotation = 30,fontsize = 'small')
#ax.set_xlabel('Stages')
#ax.set_title('i LOVE LEARN')
props = {
    'title':'Myfirst',
    'xlabel':'Stage'
}
ax.set(**props)
plt.show()

# %%
fig, ax = plt.subplots(1,1,sharex =True,sharey = True)
ax.plot(np.random.randn(1000).cumsum())
ax.set_xticks = ([0,250,500,700,1000])
ax.set_xticklabels(['one','two','three','four','five'],rotation = 30,fontsize = 'small')
#ax.set_xlabel('Stages')
#ax.set_title('i LOVE LEARN')
props = {
    'title':'Myfirst',
    'xlabel':'Stage'
}
ax.set(**props)
plt.show()

# %%
# 添加图例

# %%
# leggend 图例是另一种用于标识图标元素的重要工具

# %%
# 添加图例的最简单的方式是添加subplot的时候传入label参数

# %%
from numpy.random import randn

# %%
fig, ax  = plt.subplots(1,1)

# %%
ax.plot(randn(1000).cumsun(),'k',label = 'one')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-3f42d7242956> in <module>()
# ----> 1 ax.plot(randn(1000).cumsun(),'k',label = 'one')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'cumsun'

# %%
ax.plot(randn(1000).cumsum(),'k',label = 'one')

# %%
plt.show()

# %%
fig, ax  = plt.subplots(1,1)
ax.plot(randn(1000).cumsun(),'k',label = 'one')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-411c830d1ada> in <module>()
#       1 fig, ax  = plt.subplots(1,1)
# ----> 2 ax.plot(randn(1000).cumsun(),'k',label = 'one')
#       3 plt.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'cumsun'

# %%
fig, ax  = plt.subplots(1,1)
ax.plot(randn(1000).cumsum(),'k',label = 'one')
plt.show()

# %%
fig, ax  = plt.subplots(1,1)
ax.plot(randn(1000).cumsum(),'k',label = 'one')
plt.show()

# %%
fig, ax  = plt.subplots(1,1)
ax.plot(randn(1000).cumsum(),'k',label = 'one')
ax.plot(randn(1000).cumsum(),'k--',label = 'two')
plt.show()

# %%
fig, ax  = plt.subplots(1,1)
ax.plot(randn(1000).cumsum(),'k',label = 'one')
ax.plot(randn(1000).cumsum(),'k--',label = 'two')
ax.legend(loc = 'best')
plt.show()

# %%
fig, ax  = plt.subplots(1,1)
ax.plot(randn(1000).cumsum(),'k',label = 'one')
ax.plot(randn(1000).cumsum(),'k--',label = 'two')
ax.legend(loc = 'best')
plt.show()

# %%
ax.lengen?
# Out:
# Object `ax.lengen` not found.

# %%
ax.legend?

# %%
# 注解以及在subplots上绘图

# %%
# text arrow 和 annotate函数可以添加注解和文字

# %%
fig, ax  = plt.subplots(1,1)
ax.plot(randn(1000).cumsum(),'k',label = 'one')
ax.plot(randn(1000).cumsum(),'k--',label = 'two')
ax.legend(loc = 'best')
ax.text(x,y,'Hello',family = 'monospace',fontsize = 10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-68d8ae786cd8> in <module>()
#       3 ax.plot(randn(1000).cumsum(),'k--',label = 'two')
#       4 ax.legend(loc = 'best')
# ----> 5 ax.text(x,y,'Hello',family = 'monospace',fontsize = 10)
#       6 plt.show()
#
# NameError: name 'x' is not defined

# %%
from datetime import datetime

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

data = pd.read_csv('examples/spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']

spx.plot(ax=ax, style='k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 75),
                xytext=(date, spx.asof(date) + 225),
                arrowprops=dict(facecolor='black', headwidth=4, width=2,
                                headlength=4),
                horizontalalignment='left', verticalalignment='top')

# Zoom in on 2007-2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])

ax.set_title('Important dates in the 2008-2009 financial crisis')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-a1fd21bc1b22> in <module>()
#       4 ax = fig.add_subplot(1, 1, 1)
#       5
# ----> 6 data = pd.read_csv('examples/spx.csv', index_col=0, parse_dates=True)
#       7 spx = data['SPX']
#       8
#
# NameError: name 'pd' is not defined

# %%
from datetime import datetime

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

data = pd.read_csv('examples/spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']

spx.plot(ax=ax, style='k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 75),
                xytext=(date, spx.asof(date) + 225),
                arrowprops=dict(facecolor='black', headwidth=4, width=2,
                                headlength=4),
                horizontalalignment='left', verticalalignment='top')

# Zoom in on 2007-2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])


ax.set_title('Important dates in the 2008-2009 financial crisis')
plt.show()

# %%
from datetime import datetime

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

data = pd.read_csv('examples/spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']

spx.plot(ax=ax, style='k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 75),
                xytext=(date, spx.asof(date) + 225),
                arrowprops=dict(facecolor='black', headwidth=4, width=2,
                                headlength=4),
                horizontalalignment='left', verticalalignment='top')

# Zoom in on 2007-2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])


ax.set_title('Important dates in the 2008-2009 financial crisis')
plt.show()

# %%
data
# Out:
#                 SPX
# 1990-02-01   328.79
# 1990-02-02   330.92
# 1990-02-05   331.85
# 1990-02-06   329.66
# 1990-02-07   333.75
# 1990-02-08   332.96
# 1990-02-09   333.62
# 1990-02-12   330.08
# 1990-02-13   331.02
# 1990-02-14   332.01
# 1990-02-15   334.89
# 1990-02-16   332.72
# 1990-02-20   327.99
# 1990-02-21   327.67
# 1990-02-22   325.70
# 1990-02-23   324.15
# 1990-02-26   328.67
# 1990-02-27   330.26
# 1990-02-28   331.89
# 1990-03-01   332.74
# 1990-03-02   335.54
# 1990-03-05   333.74
# 1990-03-06   337.93
# 1990-03-07   336.95
# 1990-03-08   340.27
# 1990-03-09   337.93
# 1990-03-12   338.67
# 1990-03-13   336.00
# 1990-03-14   336.87
# 1990-03-15   338.07
# ...             ...
# 2011-09-02  1173.97
# 2011-09-06  1165.24
# 2011-09-07  1198.62
# 2011-09-08  1185.90
# 2011-09-09  1154.23
# 2011-09-12  1162.27
# 2011-09-13  1172.87
# 2011-09-14  1188.68
# 2011-09-15  1209.11
# 2011-09-16  1216.01
# 2011-09-19  1204.09
# 2011-09-20  1202.09
# 2011-09-21  1166.76
# ...

# %%
data.deccribe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-caac86ade19a> in <module>()
# ----> 1 data.deccribe()
#
# F:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'deccribe'

# %%
data.describe()
# Out:
#                SPX
# count  5472.000000
# mean    945.035216
# std     369.494672
# min     295.460000
# 25%     547.217500
# 50%    1058.305000
# 75%    1253.395000
# max    1565.150000

# %%
data.head()
# Out:
#                SPX
# 1990-02-01  328.79
# 1990-02-02  330.92
# 1990-02-05  331.85
# 1990-02-06  329.66
# 1990-02-07  333.75

# %%
# 利用plt.savefig 可以将图标保存到文件。该方法相当于 Figure 对象的实例方法 savefig

# %%
#将图标保存为 SVG 文件，   plt.savefig('figpath.svg')

# %%
# savefig  dpi:图像分辨率（每英寸点数）默认为100  bbox_inches 图标需要保存的部分 设置为'tight‘则将尝试剪除图标周围的空白部分’

# %%
# 使用 pandas 和 seaborn 绘图

# %%
# 默认轻快下，生成线性图

# %%
s = pd.Series(np.random.randn(10).cumsun(),index=np.arange(0,100,10))
s.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-107-d4e95f45ad2d> in <module>()
# ----> 1 s = pd.Series(np.random.randn(10).cumsun(),index=np.arange(0,100,10))
#       2 s.plot()
#       3 plt.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'cumsun'

# %%
s = pd.Series(np.random.randn(10).cumsum(),index=np.arange(0,100,10))
s.plot()
plt.show()

# %%
# plot.bar() 和 plot.bath() 分别绘制水平和垂直柱状图 SE 和 DF 的索引将会被用作X(BAR)

# %%
fig,ax = plot.subplots(2,1)
data = pd.Series(np.random.randn(16),index = list('abcdefghijklmnop'))
data.plot.bar(ax = ax[0],color = 'k', alpha = 0.7)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-110-f70e3a217729> in <module>()
# ----> 1 fig,ax = plot.subplots(2,1)
#       2 data = pd.Series(np.random.randn(16),index = list('abcdefghijklmnop'))
#       3 data.plot.bar(ax = ax[0],color = 'k', alpha = 0.7)
#       4 plt.show()
#
# NameError: name 'plot' is not defined

# %%
fig,ax = plt.subplots(2,1)
data = pd.Series(np.random.randn(16),index = list('abcdefghijklmnop'))
data.plot.bar(ax = ax[0],color = 'k', alpha = 0.7)
plt.show()

# %%
fig,ax = plt.subplots(2,1)
data = pd.Series(np.random.randn(16),index = list('abcdefghijklmnop'))
data.plot.bar(ax = ax[0],color = 'k', alpha = 0.7)
plt.show()

# %%
fig,ax = plt.subplots(2,1)
data = pd.Series(np.random.rand(16),index = list('abcdefghijklmnop'))
data.plot.bar(ax = ax[0],color = 'k', alpha = 0.7)
plt.show()

# %%
fig,ax = plt.subplots(2,1)
data = pd.Series(np.random.randn(16),index = list('abcdefghijklmnop'))
data.plot.bar(ax = ax[0],color = 'k', alpha = 0.7)
data.plot.barh(ax=ax[1],color = 'k',alpha = 0.7)
plt.show()

# %%
fig,ax = plt.subplots(2,1)
data = pd.Series(np.random.rand(16),index = list('abcdefghijklmnop'))
data.plot.bar(ax = ax[0],color = 'k', alpha = 0.7)
data.plot.barh(ax=ax[1],color = 'k',alpha = 0.7)
plt.show()

# %%
df = pd.DataFrame(np.random.rand(6,4),index= ['one','two','three','four','five','six'],columns=pd.Index(['A','B','C','D'],name = 'Ggg'))

# %%
df
# Out:
# Ggg           A         B         C         D
# one    0.870075  0.166437  0.339614  0.750326
# two    0.478765  0.655077  0.188474  0.660388
# three  0.200055  0.025967  0.927920  0.273211
# four   0.129029  0.827233  0.052167  0.131461
# five   0.985247  0.633540  0.022326  0.178931
# six    0.370465  0.361706  0.679091  0.894620

# %%
df.plot.bar()

# %%
plt.show()

# %%
# 柱状图有一个非常不错的用法，利用value_counts图形化显示Seriexs中各值的出现频率

# %%
fig,ax = plt.subplots(2,1)
data = pd.Series(np.random.rand(16),index = list('abcdefghijklmnop'))
data.value_counts().plot.bar(ax = ax[0],color = 'k', alpha = 0.7)
data.plot.barh(ax=ax[1],color = 'k',alpha = 0.7)
plt.show()

# %%
fig,ax = plt.subplots(2,1)
data = pd.Series(np.random.rand(16),index = list('abcdefghijklmnop'))
data.value_counts().plot.bar(ax = ax[0],color = 'k', alpha = 0.7)
data.value_counts().plot.barh(ax=ax[1],color = 'k',alpha = 0.7)
plt.show()

# %%
tips = pd.read_csv('examples/tips.csv')

# %%
parrty_counts = pd.crosstab(tips['day'],tips['size'])

# %%
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size
# 0       16.99  1.01     No  Sun  Dinner     2
# 1       10.34  1.66     No  Sun  Dinner     3
# 2       21.01  3.50     No  Sun  Dinner     3
# 3       23.68  3.31     No  Sun  Dinner     2
# 4       24.59  3.61     No  Sun  Dinner     4

# %%
parrty_counts.head()
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
parrty_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
parrty_counts = parrty_counts.loc[:,2:5]

# %%
party_pcts = parrty_counts.div(parrty_counts.sum(1),axis = 0)

# %%
party_pcts
# Out:
# size         2         3         4         5
# day
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000
# Thur  0.827586  0.068966  0.086207  0.017241

# %%
party_pcts.plot.bar()

# %%
plt.show()

# %%
import seaborna as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-142-c996ea95c4c4> in <module>()
# ----> 1 import seaborna as sns
#
# ModuleNotFoundError: No module named 'seaborna'

# %%
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tips'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# F:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tips'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-143-166744c2e5b7> in <module>()
# ...

# %%
import pandas as pd

# %%
import numpy as np

# %%
tips = pd.read_csv('examples/tips.csv')

# %%
tips['tip_pct'] = tips['tip'] / tips['total_bill']

# %%
tips['tip_pct'].hist(bins = 50)

# %%
import matplotlib.pyplot as plt

# %%
plt.show()

# %%
tips['tip_pct'].plot(kind = 'kde')

# %%
plt.show()

# %%
comp1 = np.random.normal(0,1,size = 200)

# %%
comp2 = np.random.normal(10,2,size = 200)

# %%
values = pd.Series(np.concatenate([comp1,comp2]))

# %%
values.hist(bins = 100,alpha = 0.3,color = 'k',normed = True)

# %%
values.plot(kind = 'kde',style = 'k--')

# %%
plt.show()

# %%
mcro = pd.read_csv('examples/macrodata.csv')

# %%
macro.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f69e31e0f682> in <module>()
# ----> 1 macro.describe()
#
# NameError: name 'macro' is not defined

# %%
mcro.describe()
# Out:
#               year     quarter       realgdp     realcons      realinv  \
# count   203.000000  203.000000    203.000000   203.000000   203.000000
# mean   1983.876847    2.492611   7221.171901  4825.293103  1012.863862
# std      14.686817    1.118563   3214.956044  2313.346192   585.102267
# min    1959.000000    1.000000   2710.349000  1707.400000   259.764000
# 25%    1971.000000    1.500000   4440.103500  2874.100000   519.147500
# 50%    1984.000000    2.000000   6559.594000  4299.900000   896.210000
# 75%    1996.500000    3.000000   9629.346500  6398.150000  1436.681500
# max    2009.000000    4.000000  13415.266000  9363.600000  2264.721000
#
#           realgovt       realdpi         cpi           m1    tbilrate  \
# count   203.000000    203.000000  203.000000   203.000000  203.000000
# mean    663.328640   5310.540887  105.075788   667.927586    5.311773
# std     140.863655   2423.515977   61.278878   455.346381    2.803071
# ...

# %%
data = mcro[['cpi','m1','tbilrate','unemp']]

# %%
trans_data = np.log(data).diff().dropna()

# %%
trans_data
# Out:
#           cpi        m1  tbilrate     unemp
# 1    0.005849  0.014215  0.088193 -0.128617
# 2    0.006838 -0.008505  0.215321  0.038466
# 3    0.000681 -0.003565  0.125317  0.055060
# 4    0.005772 -0.002861 -0.212805 -0.074108
# 5    0.000338  0.004289 -0.266946  0.000000
# 6    0.006745  0.004980 -0.127155  0.074108
# 7    0.003021  0.001418 -0.030110  0.117783
# 8   -0.001006  0.007062  0.034338  0.076373
# 9    0.003683  0.005614 -0.034338  0.028988
# 10   0.002003  0.008362  0.013015 -0.028988
# 11   0.001999  0.007605  0.113944 -0.092373
# 12   0.005643  0.008230  0.048790 -0.101783
# 13   0.000331  0.000683  0.018149 -0.018019
# 14   0.005281  0.001364  0.000000  0.018019
# 15   0.001973  0.010848  0.031861 -0.018019
# 16   0.001313  0.009396  0.010399  0.053110
# 17   0.006866  0.010631  0.043852 -0.017392
# 18   0.001953  0.008555  0.109313 -0.035718
# 19   0.006160  0.007183  0.040585  0.018019
# 20   0.000323  0.007131 -0.002845 -0.018019
# ...

# %%
plt.scatter(trans_data['m1'],trans_data['unemp'])

# %%
plt.title('chchhchc')

# %%
plt.show()

# %%
pd.scatter_matrix(trans_data,diagonal='kde',color = 'k',alpha=0.3)
# Out:
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002A6D029F8D0>,
# ...
#       dtype=object)

# %%
plt.show()
